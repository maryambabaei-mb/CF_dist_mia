# %% [markdown]
# 0- Here we need to use 2 different python environments, because dice_gradient uses Tensorflow and scfe uses Pytorch.
#
# when generating counterfactuals, or running cf_distance_attack attack with dice_gradient, please use the environment in tfdice_requirements.txt
#
# when generating counterfactuals or running attack for other cf_methods, please use the environment in cfdist_requirements.txt

# %% [markdown]
# 1- The first step of the project, is training the models.
#
# for each dataset (adult, acs_income, ...) run MIA_model_trainer_TF.py, with cf_method name. this is because for each cf_method we define the explainer here and save it.
#
# #Exception: for scfe method model training and cf_generation is done in one python script, train_model_scfe_parallel.py

# %%
# !python MIA_model_trainer_TF.py --dataset adult --rseed 2 --model RF --cf_method dice_gradient

# %% [markdown]
# 2- Now that all counterfactuals are generated and saved, we can (A) generate the attack dataset for nobox ensemble attack, and (A) analyse CF statistics statistics
#
# 2-A. Run new_mia_dataloader for all seeds, datasets, and cf_methods to convert CF files to synthetic data files and create attack datasets.

# %%
srun python new_MIA_dataloader.py --dataset adult --rseed 2 --cf_method dice_gradient

# %% [markdown]
# 2-B to analyse CF statistics:
#
#     1. run CF_resutl_analysis_updateformia.py
#
#     2. run cf_visuasualize_results_updateformia.py
#
#     3. run aggregation_updateformia.py
#
# for all datasets and all methods to get aggregated results

# %% [markdown]
# Now, we have everything ready to run the ensemble attack. Move generated attack dataset and synthetic data to the ensemble-mia attack folder and go through its execution guide to continue.

# %% [markdown]
# 3- Run cf_distance_attack for all datasets, cf_methods, and random seeds.

# %%
srun python cf_distance_attack.py --dataset adult --rseed 2 --cf_method dice_gradient

# %% [markdown]
# To analyze and aggregate attack restuls, run
# 1. attack_results_analysis.py for all datasets
# 2. to draw attack result figures, run to get final unified graphs and evaluation tables
#     run draw_plots_cf_distance_attack.py to get
